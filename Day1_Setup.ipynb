# %% [markdown]
# <a href="https://colab.research.google.com/github/Malleswari-275/ai-student-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid describes a hierarchy of AI capabilities, from basic sensing to advanced collaboration:
#
# *   **Base Layer - Perception:** AI's ability to sense and gather raw data from the environment (e.g., vision, speech, text).
# *   **Second Layer - Cognition:** AI processes and understands the meaning, context, and relationships within the perceived data.
# *   **Mid-Layers - Reasoning & Action:** AI applies logic, makes decisions, solves problems, and generates tangible outputs or actions based on its understanding.
# *   **Apex Layer - Collaboration & Adaptation:** The highest level, where AI continuously learns, adapts, and works synergistically with humans or achieves advanced autonomy.
